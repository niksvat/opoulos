# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.6/314.6 kB 12.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 22.9 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.0/73.0 kB 46.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 124.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 39.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 42.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 39.4 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")

# %%
msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
msft.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         14   13     6     0           1
# 1    -1m         21   30     4     0           0
# 2    -2m         20   30     4     0           0
# 3    -3m         20   27     6     0           0

# %%
msft.recommendations_summary
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         14   13     6     0           1
# 1    -1m         21   30     4     0           0
# 2    -2m         20   30     4     0           0
# 3    -3m         20   27     6     0           0

# %%
hist = msft.history(period="1mo")

# %%
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-02-23 00:00:00-05:00  415.670013  415.859985  408.970001  410.339996
# 2024-02-26 00:00:00-05:00  411.459991  412.160004  407.359985  407.540009
# 2024-02-27 00:00:00-05:00  407.989990  408.320007  403.850006  407.480011
# 2024-02-28 00:00:00-05:00  408.179993  409.299988  405.320007  407.720001
# 2024-02-29 00:00:00-05:00  408.640015  414.200012  405.920013  413.640015
# 2024-03-01 00:00:00-05:00  411.269989  415.869995  410.880005  415.500000
# 2024-03-04 00:00:00-05:00  413.440002  417.350006  412.320007  414.920013
# 2024-03-05 00:00:00-05:00  413.959991  414.250000  400.640015  402.649994
# 2024-03-06 00:00:00-05:00  402.970001  405.160004  398.390015  402.089996
# 2024-03-07 00:00:00-05:00  406.119995  409.779999  402.239990  409.140015
# 2024-03-08 00:00:00-05:00  407.959991  410.420013  404.329987  406.220001
# 2024-03-11 00:00:00-04:00  403.760010  405.679993  401.260010  404.519989
# ...

# %%
hist = msft.history(period="1mo")

# %% [markdown]
# # hist

# %%
hist["avgHL"] = (hist["High"] + hist["Low"]) / 2

# %%
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-02-23 00:00:00-05:00  415.670013  415.859985  408.970001  410.339996
# 2024-02-26 00:00:00-05:00  411.459991  412.160004  407.359985  407.540009
# 2024-02-27 00:00:00-05:00  407.989990  408.320007  403.850006  407.480011
# 2024-02-28 00:00:00-05:00  408.179993  409.299988  405.320007  407.720001
# 2024-02-29 00:00:00-05:00  408.640015  414.200012  405.920013  413.640015
# 2024-03-01 00:00:00-05:00  411.269989  415.869995  410.880005  415.500000
# 2024-03-04 00:00:00-05:00  413.440002  417.350006  412.320007  414.920013
# 2024-03-05 00:00:00-05:00  413.959991  414.250000  400.640015  402.649994
# 2024-03-06 00:00:00-05:00  402.970001  405.160004  398.390015  402.089996
# 2024-03-07 00:00:00-05:00  406.119995  409.779999  402.239990  409.140015
# 2024-03-08 00:00:00-05:00  407.959991  410.420013  404.329987  406.220001
# 2024-03-11 00:00:00-04:00  403.760010  405.679993  401.260010  404.519989
# ...

# %%
span = 20  # You can adjust the span parameter as needed
hist['EMA20'] = hist['avgHL'].ewm(span=span, adjust=False).mean()

# %%
hist.drop('EMA', axis = 1)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-02-23 00:00:00-05:00  415.670013  415.859985  408.970001  410.339996
# 2024-02-26 00:00:00-05:00  411.459991  412.160004  407.359985  407.540009
# 2024-02-27 00:00:00-05:00  407.989990  408.320007  403.850006  407.480011
# 2024-02-28 00:00:00-05:00  408.179993  409.299988  405.320007  407.720001
# 2024-02-29 00:00:00-05:00  408.640015  414.200012  405.920013  413.640015
# 2024-03-01 00:00:00-05:00  411.269989  415.869995  410.880005  415.500000
# 2024-03-04 00:00:00-05:00  413.440002  417.350006  412.320007  414.920013
# 2024-03-05 00:00:00-05:00  413.959991  414.250000  400.640015  402.649994
# 2024-03-06 00:00:00-05:00  402.970001  405.160004  398.390015  402.089996
# 2024-03-07 00:00:00-05:00  406.119995  409.779999  402.239990  409.140015
# 2024-03-08 00:00:00-05:00  407.959991  410.420013  404.329987  406.220001
# 2024-03-11 00:00:00-04:00  403.760010  405.679993  401.260010  404.519989
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.4/159.4 kB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 3.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.4/313.4 kB 7.8 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 5.0 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 6.2 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 5.3 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 8.5 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 12))
plt.plot(hist['High'], label='High')
plt.plot(hist['Low'], label='Low')
plt.plot(hist['EMA20'], label='EMA20')
plt.legend()
plt.show()

# %%
span = 50  # You can adjust the span parameter as needed
hist['EMA50'] = hist['avgHL'].ewm(span=span, adjust=False).mean()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 12))
plt.plot(hist['High'], label='High')
plt.plot(hist['Low'], label='Low')
plt.plot(hist['EMA20'], label='EMA20')
plt.plot(hist['EMA50'], label='EMA50')
plt.legend()
plt.show()

# %%
span = 7  # You can adjust the span parameter as needed
hist['EMA7'] = hist['avgHL'].ewm(span=span, adjust=False).mean()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 12))
plt.plot(hist['High'], label='High')
plt.plot(hist['Low'], label='Low')
plt.plot(hist['EMA20'], label='EMA20')
plt.plot(hist['EMA50'], label='EMA50')
plt.plot(hist['EMA7'], label='EMA7')
plt.legend()
plt.show()
